# %%
import numpy as np
import pandas as pd

# %% [markdown]
# PRE-PROCESSING STRUCTURE
#
# 1. Load raw
# 2. Set montage
# 3. Rename channels if needed
# 4. Set channel types (EOG, ECG)
# 5. Filter (1–100 Hz)
# 6. Notch (50 Hz)
# 7. Detect bad channels (auto + manual check)
# 8. Interpolate bad channels
# 9. Re-reference (average reference)
# 10. Run ICA (remove blink + ECG artifacts)
# 11. Extract events
# 12. Assign phases
# 13. Contextualize behavioral meaning
# 14. Epoch by context label
